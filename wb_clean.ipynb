# %%
import pandas as pd

# %%
try:
    df = pd.read_csv('API_AG.YLD.CREL.KG_DS2_en_csv_v2_4156464.csv')
    df.head()
except:
    print('ParserError')
# ParserError
# The first row is metadata with only two columns.
# This does not align with the relevant data which has more than two columns.
# Out:
# ParserError

# %%
df = pd.read_csv('who_datasets/API_AG.YLD.CREL.KG_DS2_en_csv_v2_4156464.csv',
                    header=2)
df.head()
# Out:
#                   Country Name Country Code                 Indicator Name  \
# 0                        Aruba          ABW  Cereal yield (kg per hectare)
# 1  Africa Eastern and Southern          AFE  Cereal yield (kg per hectare)
# 2                  Afghanistan          AFG  Cereal yield (kg per hectare)
# 3   Africa Western and Central          AFW  Cereal yield (kg per hectare)
# 4                       Angola          AGO  Cereal yield (kg per hectare)
#
#    Indicator Code  1960         1961         1962        1963         1964  \
# 0  AG.YLD.CREL.KG   NaN          NaN          NaN         NaN          NaN
# 1  AG.YLD.CREL.KG   NaN   924.994623   941.783828  938.845615   887.762617
# 2  AG.YLD.CREL.KG   NaN  1115.100000  1079.000000  985.800000  1082.800000
# 3  AG.YLD.CREL.KG   NaN   675.354816   702.244456  698.032526   691.134187
# 4  AG.YLD.CREL.KG   NaN   828.000000   830.300000  798.400000   875.800000
#
# ...

# %%
df.shape
# Out:
# (266, 67)

# %% [markdown]
# Which columns are irrelevant?

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
type(df['Unnamed: 66'])
# Out:
# pandas.core.series.Series

# %%
u = df['Unnamed: 66']
u.shape
# Out:
# (266,)

# %% [markdown]
# - `.isna(<Series>)` returns an array of booleans.
# - If an item in the series is of the type NaN then the boolean evaluates to True.
# - o.w. False.

# %%
empty = pd.isna(u)

# %%
all(empty)
# Out:
# True

# %%
df.drop('Unnamed: 66', inplace=True, axis=1)
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
i_name = df['Indicator Name']
u = i_name.unique()
print(u)
# Out:
# ['Cereal yield (kg per hectare)']

# %%
i_code = df['Indicator Code']
u = i_code.unique()
u
# Out:
# array(['AG.YLD.CREL.KG'], dtype=object)

# %%
to_drop = ['Indicator Name', 'Indicator Code']
df.drop(to_drop, inplace=True, axis=1)
df.head()
# Out:
#                   Country Name Country Code  1960         1961         1962  \
# 0                        Aruba          ABW   NaN          NaN          NaN
# 1  Africa Eastern and Southern          AFE   NaN   924.994623   941.783828
# 2                  Afghanistan          AFG   NaN  1115.100000  1079.000000
# 3   Africa Western and Central          AFW   NaN   675.354816   702.244456
# 4                       Angola          AGO   NaN   828.000000   830.300000
#
#          1963         1964         1965         1966         1967  ...  \
# 0         NaN          NaN          NaN          NaN          NaN  ...
# 1  938.845615   887.762617   883.767706   901.427494  1136.132897  ...
# 2  985.800000  1082.800000  1098.900000  1012.300000  1224.500000  ...
# 3  698.032526   691.134187   658.343442   643.872508   684.305251  ...
# 4  798.400000   875.800000   932.000000   824.300000   814.600000  ...
#
#           2012         2013         2014         2015         2016  \
# ...

# %%
df.dtypes
# Out:
# Country Name     object
# Country Code     object
# 1960            float64
# 1961            float64
# 1962            float64
#                  ...
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# Length: 64, dtype: object

# %%
df['Country Name'][0]
# Out:
# 'Aruba'

# %%
type(df['Country Code'])
# Out:
# pandas.core.series.Series

# %%
type(df['Country Name'])
# Out:
# pandas.core.series.Series

# %%
df['Country Code'].shape == df['Country Name'].shape
# Out:
# True

# %% [markdown]
# - Hash table maps full country name to abbreviated country code.

# %%
country_code = dict(zip(df['Country Name'], df['Country Code']))
country_code['Aruba']
# Out:
# 'ABW'

# %%
country_code['Russian Federation']
# Out:
# 'RUS'

# %%
df['Country Code'].is_unique
# Out:
# True

# %%
df.head()
# Out:
#                   Country Name Country Code  1960         1961         1962  \
# 0                        Aruba          ABW   NaN          NaN          NaN
# 1  Africa Eastern and Southern          AFE   NaN   924.994623   941.783828
# 2                  Afghanistan          AFG   NaN  1115.100000  1079.000000
# 3   Africa Western and Central          AFW   NaN   675.354816   702.244456
# 4                       Angola          AGO   NaN   828.000000   830.300000
#
#          1963         1964         1965         1966         1967  ...  \
# 0         NaN          NaN          NaN          NaN          NaN  ...
# 1  938.845615   887.762617   883.767706   901.427494  1136.132897  ...
# 2  985.800000  1082.800000  1098.900000  1012.300000  1224.500000  ...
# 3  698.032526   691.134187   658.343442   643.872508   684.305251  ...
# 4  798.400000   875.800000   932.000000   824.300000   814.600000  ...
#
#           2012         2013         2014         2015         2016  \
# ...

# %% [markdown]
# - Change index to country codes.

# %%
df.set_index(df.columns[1], inplace=True)
df.head()
# Out:
#                              Country Name  1960         1961         1962  \
# Country Code
# ABW                                 Aruba   NaN          NaN          NaN
# AFE           Africa Eastern and Southern   NaN   924.994623   941.783828
# AFG                           Afghanistan   NaN  1115.100000  1079.000000
# AFW            Africa Western and Central   NaN   675.354816   702.244456
# AGO                                Angola   NaN   828.000000   830.300000
#
#                     1963         1964         1965         1966         1967  \
# Country Code
# ABW                  NaN          NaN          NaN          NaN          NaN
# AFE           938.845615   887.762617   883.767706   901.427494  1136.132897
# AFG           985.800000  1082.800000  1098.900000  1012.300000  1224.500000
# AFW           698.032526   691.134187   658.343442   643.872508   684.305251
# AGO           798.400000   875.800000   932.000000   824.300000   814.600000
#
# ...

# %%
df['1960']['RUS']
# Out:
# nan

# %%
df.describe()
# Out:
#        1960         1961         1962         1963         1964         1965  \
# count   0.0   195.000000   195.000000   195.000000   195.000000   195.000000
# mean    NaN  1318.831486  1391.802003  1395.945308  1425.253969  1450.139000
# std     NaN   747.991251   784.680917   762.392229   817.232448   815.062533
# min     NaN   214.700000   221.000000   255.300000   235.000000   329.800000
# 25%     NaN   824.189939   874.000000   858.522974   858.942504   882.933853
# 50%     NaN  1107.800000  1164.000000  1194.700000  1183.700000  1197.100000
# 75%     NaN  1689.197297  1626.934443  1736.726480  1701.298646  1767.293667
# max     NaN  4173.500000  4339.600000  4224.000000  4395.800000  4398.200000
#
#               1966         1967         1968         1969  ...          2012  \
# count   196.000000   196.000000   197.000000   197.000000  ...    228.000000
# mean   1447.866396  1528.622426  1539.487607  1569.014777  ...   3207.836450
# ...

# %%
tdf = df.T

# %%
tdf.head()
# Out:
# Country Code    ABW                          AFE          AFG  \
# Country Name  Aruba  Africa Eastern and Southern  Afghanistan
# 1960            NaN                          NaN          NaN
# 1961            NaN                   924.994623       1115.1
# 1962            NaN                   941.783828       1079.0
# 1963            NaN                   938.845615        985.8
#
# Country Code                         AFW     AGO      ALB      AND  \
# Country Name  Africa Western and Central  Angola  Albania  Andorra
# 1960                                 NaN     NaN      NaN      NaN
# 1961                          675.354816   828.0    845.2      NaN
# 1962                          702.244456   830.3    941.8      NaN
# 1963                          698.032526   798.4    982.3      NaN
#
# Country Code          ARB                   ARE        ARG  ...  \
# Country Name   Arab World  United Arab Emirates  Argentina  ...
# ...

# %%
tdf.describe()
# Out:
# Country Code    ABW                          AFE     AFG  \
# count             1                           59    59.0
# unique            1                           59    58.0
# top           Aruba  Africa Eastern and Southern  1285.7
# freq              1                            1     2.0
#
# Country Code                         AFW    AGO      ALB      AND         ARB  \
# count                                 59   59.0       59        1          59
# unique                                59   58.0       59        1          59
# top           Africa Western and Central  805.7  Albania  Andorra  Arab World
# freq                                   1    2.0        1        1           1
#
# Country Code                   ARE        ARG  ...                    VIR  \
# count                           43         59  ...                      1
# unique                          43         59  ...                      1
# ...
